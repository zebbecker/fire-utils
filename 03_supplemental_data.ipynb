# %% [markdown]
# There are a few more files we need to start running FEDS locally.
#
# Download from MAAP ADE using the GUI:
#
# - shared-buckets/gsfc_landslides/FEDSinput/static_sources/VIIRS_Global_flaring_d.7_slope_0.029353_2017_web_v1.csv
# - shared-buckets/gsfc_landslides/FEDSpreprocessed/nlcd_export_510m_simplified_latlon.tif
# - shared-buckets/gsfc_landslides/FEDSinput/Shapefiles/*.geojson

# %%
# assumes we have downloaded static sources from MAAP ADE using GUI
# !mkdir -p ~/Desktop/fireatlas/data/FEDSinput/static_sources/
# !cp ~/Downloads/VIIRS_Global_flaring_d.7_slope_0.029353_2017_web_v1.csv ~/Desktop/fireatlas/data/FEDSinput/static_sources/

# %%
# !mkdir -p ~/Desktop/fireatlas/data/FEDSpreprocessed/
# !cp ~/Downloads/nlcd_export_510m_simplified_latlon.tif ~/Desktop/fireatlas/data/FEDSpreprocessed/

# %%
# !mkdir -p ~/Desktop/fireatlas/data/FEDSinput/Shapefiles/
# !cp ~/Downloads/*.geojson ~/Desktop/fireatlas/data/FEDSinput/Shapefiles/
# careful!
