# %%
from maap.maap import MAAP
maap = MAAP(maap_host='api.maap-project.org')

# %%
res = maap.register_algorithm_from_yaml_file("algo_configs/eis-nifc-scraper.yml")
print(res.text)
# Out:
# {"code": 200, "message": {"id": "4540a4cd757d4d4fc55977844073309ab89c6e16", "short_id": "4540a4cd", "created_at": "2026-07-01T15:52:44.000+00:00", "parent_ids": ["281230a93290e274ba67178374751c0275b83d49"], "title": "Registering algorithm: eis-nifc-scraper", "message": "Registering algorithm: eis-nifc-scraper", "author_name": "root", "author_email": "root@6fb29d2158a6", "authored_date": "2026-07-01T15:52:44.000+00:00", "committer_name": "root", "committer_email": "root@6fb29d2158a6", "committed_date": "2026-07-01T15:52:44.000+00:00", "trailers": {}, "extended_trailers": {}, "web_url": "https://repo.maap-project.org/root/register-job-hysds-v4/-/commit/4540a4cd757d4d4fc55977844073309ab89c6e16", "stats": {"additions": 2, "deletions": 2, "total": 4}, "status": "pending", "project_id": 3, "last_pipeline": {"id": 18919, "iid": 3829, "project_id": 3, "sha": "4540a4cd757d4d4fc55977844073309ab89c6e16", "ref": "hysds-v5", "status": "pending", "source": "push", "created_at": "2026-07-01T15:52:4
# ...

# %% [markdown]
# Click on "job_web_url" in the response above to monitor the DPS image build and ensure it completes successfully.
